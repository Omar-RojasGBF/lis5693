# %% [markdown]
# <a href="https://colab.research.google.com/github/Omar-RojasGBF/lis5693/blob/main/lab-6/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textnets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 60.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 70.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
# ...

# %%
import textnets as tn

# %%
tn.params
# Out:
# Parameter              Value
# --------------------   --------------
# seed                   2300
# autodownload           False
# figsize                (16, 9)
# lang                   en_core_web_sm
# progress_bar           True
# resolution_parameter   0.1
# tuning_parameter       0.5

# %%
tn.params["seed"] = 42

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Omar-RojasGBF/lis5693/refs/heads/main/lab-5/lens-export.csv"
df = pd.read_csv("https://raw.githubusercontent.com/Omar-RojasGBF/lis5693/refs/heads/main/lab-5/lens-export.csv")

# %%
df
# Out:
#                  Lens ID                                              Title  \
# 0    000-122-744-113-792  Editor's Note: EGFR Activation and Signaling i...
# 1    000-935-967-706-286  1566P Clinical relevance of circulating tumor ...
# 2    000-963-992-163-111  Regulating Tumorigenicity and Cancer Metastasi...
# 3    000-965-490-020-750  Correction: Lysyl Oxidase-like Protein LOXL2 P...
# 4    001-126-801-426-66X  ASO Author Reflections: Diagnosis and Treatmen...
# ..                   ...                                                ...
# 995  198-737-187-079-422  Correction: Proliferation and AKT Activity Bio...
# 996  199-406-826-268-941  Head & Neck Oncology Track: Carotid Resection ...
# 997  199-434-748-233-097  Editor's Note: Deciphering the Mechanisms of T...
# 998  199-536-842-016-504          Defining concepts in cancer survivorship.
# 999  199-793-269-625-872                            Cancer. Cancer cachexia
#
#     Date Published  Publication Year Publication Type  \
# ...

# %%
corpus = df['Publisher'].astype(str).tolist()

# %%
corpus
# Out:
# ['American Association for Cancer Research (AACR)',
#  'Elsevier BV',
#  'Bentham Science Publishers Ltd.',
#  'American Association for Cancer Research (AACR)',
#  'Springer Science and Business Media LLC',
#  'Springer Science and Business Media LLC',
#  'Elsevier BV',
#  'Springer Science and Business Media LLC',
#  'American Association for Cancer Research (AACR)',
#  'Elsevier BV',
#  'Elsevier BV',
#  'Japan Society for Head and Neck Cancer',
#  'Japan Lung Cancer Society',
#  'Springer Science and Business Media LLC',
#  'American Association for Cancer Research (AACR)',
#  'American Chemical Society (ACS)',
#  'Massachusetts Medical Society',
#  'nan',
#  'OMICS Publishing Group',
#  'Frontiers Media SA',
#  'Elsevier BV',
#  'Springer International Publishing',
#  'American Society of Clinical Oncology (ASCO)',
#  'Elsevier BV',
#  'Elsevier Inc.',
#  'American Association for Cancer Research (AACR)',
#  'nan',
#  'H1 Connect',
# ...

# %%
tokenized_corpus = [doc.split() for doc in corpus]

# %%
tokenized_corpus
# Out:
# [['American', 'Association', 'for', 'Cancer', 'Research', '(AACR)'],
#  ['Elsevier', 'BV'],
#  ['Bentham', 'Science', 'Publishers', 'Ltd.'],
#  ['American', 'Association', 'for', 'Cancer', 'Research', '(AACR)'],
#  ['Springer', 'Science', 'and', 'Business', 'Media', 'LLC'],
#  ['Springer', 'Science', 'and', 'Business', 'Media', 'LLC'],
#  ['Elsevier', 'BV'],
#  ['Springer', 'Science', 'and', 'Business', 'Media', 'LLC'],
#  ['American', 'Association', 'for', 'Cancer', 'Research', '(AACR)'],
#  ['Elsevier', 'BV'],
#  ['Elsevier', 'BV'],
#  ['Japan', 'Society', 'for', 'Head', 'and', 'Neck', 'Cancer'],
#  ['Japan', 'Lung', 'Cancer', 'Society'],
#  ['Springer', 'Science', 'and', 'Business', 'Media', 'LLC'],
#  ['American', 'Association', 'for', 'Cancer', 'Research', '(AACR)'],
#  ['American', 'Chemical', 'Society', '(ACS)'],
#  ['Massachusetts', 'Medical', 'Society'],
#  ['nan'],
#  ['OMICS', 'Publishing', 'Group'],
#  ['Frontiers', 'Media', 'SA'],
#  ['Elsevier', 'BV'],
# ...

# %%
tokenized_corpus.plot(label_nodes=True,
       show_clusters=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6347/3184109186.py in <cell line: 0>()
# ----> 1 tokenized_corpus.plot(label_nodes=True,
#       2        show_clusters=True)
#
# AttributeError: 'list' object has no attribute 'plot'

# %% [markdown]
# Reflection 💭
#
#
# ---
# Unfortunantly, the Lab 5 was skill not working. I am not sure which point the trouble comes form, but I was able to make some tiny progress to fixing it. I might upload the new Lab 5 to my lab-5 folder to show my improvements. In general, I can see myself using text network analysis for research over spotting text patterns in research papers over library and information science. I might be useful if I plan to pursue a PhD in the future, but as a school librarian, I do not believe that I will have any reason to do so.
